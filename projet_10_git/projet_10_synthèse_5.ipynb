# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %store -r data
# %store -r model

# %%
# test de la modélisation avec un échantillon

billets_production = pd.read_csv("billets_production.csv", sep=",", decimal=',')
billets_production
# Out:
#   diagonal height_left height_right margin_low margin_up  length   id
# 0   171.76      104.01       103.54       5.21       3.3  111.42  A_1
# 1   171.87      104.17       104.13        6.0      3.31  112.09  A_2
# 2    172.0      104.58       104.29       4.99      3.39  111.57  A_3
# 3   172.49      104.55       104.34       4.44      3.03   113.2  A_4
# 4   171.65      103.63       103.56       3.77      3.16  113.33  A_5

# %%
billets_production["is_genuine"] = model.predict(billets_production.iloc[:, :-1])
billets_production
# Out:
#   diagonal height_left height_right margin_low margin_up  length   id  \
# 0   171.76      104.01       103.54       5.21       3.3  111.42  A_1
# 1   171.87      104.17       104.13        6.0      3.31  112.09  A_2
# 2    172.0      104.58       104.29       4.99      3.39  111.57  A_3
# 3   172.49      104.55       104.34       4.44      3.03   113.2  A_4
# 4   171.65      103.63       103.56       3.77      3.16  113.33  A_5
#
#    is_genuine
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1

# %%
g = sns.heatmap(data = data.corr(), 
            cmap = "RdBu", 
            annot = True, 
            linewidth = 1, 
            linecolor = "black")

# %%
# test de la modélisation avec un échantillon soutenance

billets_test = pd.read_csv("billets_test_PE_P10.csv", sep=",", decimal=',')
billets_test
# Out:
#   diagonal height_left height_right margin_low margin_up  length   id
# 0   172.09      103.95       103.73       4.39      3.09  113.19  B_1
# 1   171.52      104.17       104.03       5.27      3.16  111.82  B_2
# 2   171.78       103.8       103.75       3.81      3.24  113.39  B_3
# 3   172.02      104.08       103.99       5.57       3.3   111.1  B_4
# 4   171.79      104.34       104.37        5.0      3.07  111.87  B_5

# %%
billets_test["is_genuine"] = model.predict(billets_test.iloc[:, :-1])
billets_test
# Out:
#   diagonal height_left height_right margin_low margin_up  length   id  \
# 0   172.09      103.95       103.73       4.39      3.09  113.19  B_1
# 1   171.52      104.17       104.03       5.27      3.16  111.82  B_2
# 2   171.78       103.8       103.75       3.81      3.24  113.39  B_3
# 3   172.02      104.08       103.99       5.57       3.3   111.1  B_4
# 4   171.79      104.34       104.37        5.0      3.07  111.87  B_5
#
#    is_genuine
# 0           1
# 1           0
# 2           1
# 3           0
# 4           0
