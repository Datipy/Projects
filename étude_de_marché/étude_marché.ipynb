# %%
"""

Ce projet vise à réaliser une étude de marché afin de dégager les différents clusters à cibler selon le produit étudié.
La méthode s’appuit


"""
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#  importation des fonctions pour l’ACP
from functions import *

data = pd.read_csv("DisponibiliteAlimentaire_2017.csv")
data
# Out:
#        Code Domaine                      Domaine  Code zone         Zone  \
# 0               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 1               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 2               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 3               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 4               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# ...             ...                          ...        ...          ...
# 176595          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176596          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176597          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176598          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176599          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
#
#         Code Élément                                            Élément  \
# 0               5511                                         Production
# 1               5611                            Importations - Quantité
# 2               5072                                 Variation de stock
# 3               5911                            Exportations - Quantité
# 4               5301                           Disponibilité intérieure
# ...              ...                                                ...
# 176595          5142                                         Nourriture
# 176596           645  Disponibilité alimentaire en quantité (kg/pers...
# 176597           664     Disponibilité alimentaire (Kcal/personne/jour)
# 176598           674  Disponibilité de protéines en quantité (g/pers...
# 176599           684  Disponibilité de matière grasse en quantité (g...
#
#         Code Produit          Produit  Code année  Année               Unité  \
# 0               2511  Blé et produits        2017   2017  Milliers de tonnes
# 1               2511  Blé et produits        2017   2017  Milliers de tonnes
# 2               2511  Blé et produits        2017   2017  Milliers de tonnes
# 3               2511  Blé et produits        2017   2017  Milliers de tonnes
# 4               2511  Blé et produits        2017   2017  Milliers de tonnes
# ...              ...              ...         ...    ...                 ...
# 176595          2899     Miscellanees        2017   2017  Milliers de tonnes
# 176596          2899     Miscellanees        2017   2017                  kg
# 176597          2899     Miscellanees        2017   2017  Kcal/personne/jour
# 176598          2899     Miscellanees        2017   2017     g/personne/jour
# 176599          2899     Miscellanees        2017   2017     g/personne/jour
#
#          Valeur Symbole Description du Symbole
# 0       4281.00       S  Données standardisées
# 1       2302.00       S  Données standardisées
# 2       -119.00       S  Données standardisées
# 3          0.00       S  Données standardisées
# 4       6701.00       S  Données standardisées
# ...         ...     ...                    ...
# 176595    19.00       S  Données standardisées
# 176596     1.33      Fc        Donnée calculée
# 176597     1.00      Fc        Donnée calculée
# 176598     0.04      Fc        Donnée calculée
# 176599     0.02      Fc        Donnée calculée
#
# [176600 rows x 14 columns]

# %%
# sélection de la catégorie à étudier

data = data[data["Produit"].str.contains("Volaille")]
data
# Out:
#        Code Domaine                      Domaine  Code zone         Zone  \
# 651             FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 652             FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 653             FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 654             FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 655             FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# ...             ...                          ...        ...          ...
# 176396          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176397          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176398          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176399          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176400          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
#
#         Code Élément                                            Élément  \
# 651             5511                                         Production
# 652             5611                            Importations - Quantité
# 653             5072                                 Variation de stock
# 654             5301                           Disponibilité intérieure
# 655             5123                                             Pertes
# ...              ...                                                ...
# 176396          5142                                         Nourriture
# 176397           645  Disponibilité alimentaire en quantité (kg/pers...
# 176398           664     Disponibilité alimentaire (Kcal/personne/jour)
# 176399           674  Disponibilité de protéines en quantité (g/pers...
# 176400           684  Disponibilité de matière grasse en quantité (g...
#
#         Code Produit              Produit  Code année  Année  \
# 651             2734  Viande de Volailles        2017   2017
# 652             2734  Viande de Volailles        2017   2017
# 653             2734  Viande de Volailles        2017   2017
# 654             2734  Viande de Volailles        2017   2017
# 655             2734  Viande de Volailles        2017   2017
# ...              ...                  ...         ...    ...
# 176396          2734  Viande de Volailles        2017   2017
# 176397          2734  Viande de Volailles        2017   2017
# 176398          2734  Viande de Volailles        2017   2017
# 176399          2734  Viande de Volailles        2017   2017
# 176400          2734  Viande de Volailles        2017   2017
#
#                      Unité  Valeur Symbole Description du Symbole
# 651     Milliers de tonnes   28.00       S  Données standardisées
# 652     Milliers de tonnes   29.00       S  Données standardisées
# 653     Milliers de tonnes    0.00       S  Données standardisées
# 654     Milliers de tonnes   57.00       S  Données standardisées
# 655     Milliers de tonnes    2.00       S  Données standardisées
# ...                    ...     ...     ...                    ...
# 176396  Milliers de tonnes   67.00       S  Données standardisées
# 176397                  kg    4.68      Fc        Donnée calculée
# 176398  Kcal/personne/jour   16.00      Fc        Donnée calculée
# 176399     g/personne/jour    1.59      Fc        Donnée calculée
# 176400     g/personne/jour    0.99      Fc        Donnée calculée
#
# [2061 rows x 14 columns]

# %%
# premier filtre des variables

test = data.iloc[:, [3, 5, 10, 11]]
test.head(20)
# Out:
#                 Zone                                            Élément  \
# 651      Afghanistan                                         Production
# 652      Afghanistan                            Importations - Quantité
# 653      Afghanistan                                 Variation de stock
# 654      Afghanistan                           Disponibilité intérieure
# 655      Afghanistan                                             Pertes
# 656      Afghanistan                                            Résidus
# 657      Afghanistan                                         Nourriture
# 658      Afghanistan  Disponibilité alimentaire en quantité (kg/pers...
# 659      Afghanistan     Disponibilité alimentaire (Kcal/personne/jour)
# 660      Afghanistan  Disponibilité de protéines en quantité (g/pers...
# 661      Afghanistan  Disponibilité de matière grasse en quantité (g...
# 1704  Afrique du Sud                                         Production
# 1705  Afrique du Sud                            Importations - Quantité
# 1706  Afrique du Sud                                 Variation de stock
# 1707  Afrique du Sud                            Exportations - Quantité
# 1708  Afrique du Sud                           Disponibilité intérieure
# 1709  Afrique du Sud                                             Pertes
# 1710  Afrique du Sud                        Alimentation pour touristes
# 1711  Afrique du Sud                                            Résidus
# 1712  Afrique du Sud                                         Nourriture
#
#                    Unité   Valeur
# 651   Milliers de tonnes    28.00
# 652   Milliers de tonnes    29.00
# 653   Milliers de tonnes     0.00
# 654   Milliers de tonnes    57.00
# 655   Milliers de tonnes     2.00
# 656   Milliers de tonnes     0.00
# 657   Milliers de tonnes    55.00
# 658                   kg     1.53
# 659   Kcal/personne/jour     5.00
# 660      g/personne/jour     0.54
# 661      g/personne/jour     0.33
# 1704  Milliers de tonnes  1667.00
# 1705  Milliers de tonnes   514.00
# 1706  Milliers de tonnes    -0.00
# 1707  Milliers de tonnes    63.00
# 1708  Milliers de tonnes  2118.00
# 1709  Milliers de tonnes    83.00
# 1710  Milliers de tonnes     0.00
# 1711  Milliers de tonnes     0.00
# 1712  Milliers de tonnes  2035.00

# %%
# filtrage des variables par mot-clé

save = test[test["Élément"].str.contains("personne") == False]
save = save.drop("Unité", axis = 1)
save.head(20)
# Out:
#                 Zone                      Élément  Valeur
# 651      Afghanistan                   Production    28.0
# 652      Afghanistan      Importations - Quantité    29.0
# 653      Afghanistan           Variation de stock     0.0
# 654      Afghanistan     Disponibilité intérieure    57.0
# 655      Afghanistan                       Pertes     2.0
# 656      Afghanistan                      Résidus     0.0
# 657      Afghanistan                   Nourriture    55.0
# 1704  Afrique du Sud                   Production  1667.0
# 1705  Afrique du Sud      Importations - Quantité   514.0
# 1706  Afrique du Sud           Variation de stock    -0.0
# 1707  Afrique du Sud      Exportations - Quantité    63.0
# 1708  Afrique du Sud     Disponibilité intérieure  2118.0
# 1709  Afrique du Sud                       Pertes    83.0
# 1710  Afrique du Sud  Alimentation pour touristes     0.0
# 1711  Afrique du Sud                      Résidus     0.0
# 1712  Afrique du Sud                   Nourriture  2035.0
# 2713         Albanie                   Production    13.0
# 2714         Albanie      Importations - Quantité    38.0
# 2715         Albanie           Variation de stock     4.0
# 2716         Albanie      Exportations - Quantité     0.0

# %%
# génération d’une nouvelle table plus lisible

newdata = pd.DataFrame()
newdata["Zone"] = save["Zone"].unique()
newdata = newdata.set_index("Zone")

for i in range(len(save)):
    test = save.iloc[i, :]
    newdata.loc[test[0], test[1]] = test[2]
        
display(newdata)
newdata.info()
# Out:
#                                         Production  Importations - Quantité  \
# Zone
# Afghanistan                                   28.0                     29.0
# Afrique du Sud                              1667.0                    514.0
# Albanie                                       13.0                     38.0
# Algérie                                      275.0                      2.0
# Allemagne                                   1514.0                    842.0
# ...                                            ...                      ...
# Venezuela (République bolivarienne du)       600.0                     25.0
# Viet Nam                                     918.0                    291.0
# Yémen                                        168.0                     78.0
# Zambie                                        49.0                     12.0
# Zimbabwe                                      69.0                      6.0
#
#                                         Variation de stock  \
# Zone
# Afghanistan                                            0.0
# Afrique du Sud                                        -0.0
# Albanie                                                4.0
# Algérie                                                0.0
# Allemagne                                            -29.0
# ...                                                    ...
# Venezuela (République bolivarienne du)                -1.0
# Viet Nam                                               2.0
# Yémen                                                 -0.0
# Zambie                                                -0.0
# Zimbabwe                                              -0.0
#
#                                         Disponibilité intérieure  Pertes  \
# Zone
# Afghanistan                                                 57.0     2.0
# Afrique du Sud                                            2118.0    83.0
# Albanie                                                     47.0     NaN
# Algérie                                                    277.0    13.0
# Allemagne                                                 1739.0     NaN
# ...                                                          ...     ...
# Venezuela (République bolivarienne du)                     626.0    30.0
# Viet Nam                                                  1206.0    39.0
# Yémen                                                      246.0     8.0
# Zambie                                                      60.0     2.0
# Zimbabwe                                                    76.0     3.0
#
#                                         Résidus  Nourriture  \
# Zone
# Afghanistan                                 0.0        55.0
# Afrique du Sud                              0.0      2035.0
# Albanie                                     0.0        47.0
# Algérie                                     0.0       264.0
# Allemagne                                 -38.0      1609.0
# ...                                         ...         ...
# Venezuela (République bolivarienne du)      0.0       596.0
# Viet Nam                                    0.0      1166.0
# Yémen                                       NaN       237.0
# Zambie                                      0.0        58.0
# Zimbabwe                                    0.0        67.0
#
#                                         Exportations - Quantité  \
# Zone
# Afghanistan                                                 NaN
# Afrique du Sud                                             63.0
# Albanie                                                     0.0
# Algérie                                                     0.0
# Allemagne                                                 646.0
# ...                                                         ...
# Venezuela (République bolivarienne du)                      0.0
# Viet Nam                                                    1.0
# Yémen                                                       0.0
# Zambie                                                      1.0
# Zimbabwe                                                    NaN
#
#                                         Alimentation pour touristes  \
# Zone
# Afghanistan                                                     NaN
# Afrique du Sud                                                  0.0
# Albanie                                                         NaN
# Algérie                                                         0.0
# Allemagne                                                       NaN
# ...                                                             ...
# Venezuela (République bolivarienne du)                          0.0
# Viet Nam                                                        0.0
# Yémen                                                           NaN
# Zambie                                                          0.0
# Zimbabwe                                                        0.0
#
#                                         Traitement  \
# Zone
# Afghanistan                                    NaN
# Afrique du Sud                                 NaN
# Albanie                                        NaN
# Algérie                                        NaN
# Allemagne                                    167.0
# ...                                            ...
# Venezuela (République bolivarienne du)         NaN
# Viet Nam                                       NaN
# Yémen                                          NaN
# Zambie                                         NaN
# Zimbabwe                                       6.0
#
#                                         Autres utilisations (non alimentaire)  \
# Zone
# Afghanistan                                                               NaN
# Afrique du Sud                                                            NaN
# Albanie                                                                   NaN
# Algérie                                                                   NaN
# Allemagne                                                                 NaN
# ...                                                                       ...
# Venezuela (République bolivarienne du)                                    NaN
# Viet Nam                                                                  NaN
# Yémen                                                                     NaN
# Zambie                                                                    NaN
# Zimbabwe                                                                  NaN
#
#                                         Aliments pour animaux  Semences
# Zone
# Afghanistan                                               NaN       NaN
# Afrique du Sud                                            NaN       NaN
# Albanie                                                   NaN       NaN
# Algérie                                                   NaN       NaN
# Allemagne                                                 NaN       NaN
# ...                                                       ...       ...
# Venezuela (République bolivarienne du)                    NaN       NaN
# Viet Nam                                                  NaN       NaN
# Yémen                                                     NaN       NaN
# Zambie                                                    NaN       NaN
# Zimbabwe                                                  NaN       NaN
#
# [170 rows x 13 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 170 entries, Afghanistan to Zimbabwe
# Data columns (total 13 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Production                             168 non-null    float64
#  1   Importations - Quantité                170 non-null    float64
#  2   Variation de stock                     169 non-null    float64
#  3   Disponibilité intérieure               170 non-null    float64
#  4   Pertes                                 67 non-null     float64
#  5   Résidus                                164 non-null    float64
#  6   Nourriture                             170 non-null    float64
#  7   Exportations - Quantité                135 non-null    float64
#  8   Alimentation pour touristes            78 non-null     float64
#  9   Traitement                             46 non-null     float64
#  10  Autres utilisations (non alimentaire)  34 non-null     float64
#  11  Aliments pour animaux                  1 non-null      float64
#  12  Semences                               1 non-null      float64
# dtypes: float64(13)
# memory usage: 22.7+ KB

# %%
# élimination des variables comportant trop de valeurs manquantes dans une nouvelle table

cleandata = newdata.iloc[:, [i for i in range(0, 7)]].copy(deep = True)

display(cleandata)
cleandata.info()
# Out:
#                                         Production  Importations - Quantité  \
# Zone
# Afghanistan                                   28.0                     29.0
# Afrique du Sud                              1667.0                    514.0
# Albanie                                       13.0                     38.0
# Algérie                                      275.0                      2.0
# Allemagne                                   1514.0                    842.0
# ...                                            ...                      ...
# Venezuela (République bolivarienne du)       600.0                     25.0
# Viet Nam                                     918.0                    291.0
# Yémen                                        168.0                     78.0
# Zambie                                        49.0                     12.0
# Zimbabwe                                      69.0                      6.0
#
#                                         Variation de stock  \
# Zone
# Afghanistan                                            0.0
# Afrique du Sud                                        -0.0
# Albanie                                                4.0
# Algérie                                                0.0
# Allemagne                                            -29.0
# ...                                                    ...
# Venezuela (République bolivarienne du)                -1.0
# Viet Nam                                               2.0
# Yémen                                                 -0.0
# Zambie                                                -0.0
# Zimbabwe                                              -0.0
#
#                                         Disponibilité intérieure  Pertes  \
# Zone
# Afghanistan                                                 57.0     2.0
# Afrique du Sud                                            2118.0    83.0
# Albanie                                                     47.0     NaN
# Algérie                                                    277.0    13.0
# Allemagne                                                 1739.0     NaN
# ...                                                          ...     ...
# Venezuela (République bolivarienne du)                     626.0    30.0
# Viet Nam                                                  1206.0    39.0
# Yémen                                                      246.0     8.0
# Zambie                                                      60.0     2.0
# Zimbabwe                                                    76.0     3.0
#
#                                         Résidus  Nourriture
# Zone
# Afghanistan                                 0.0        55.0
# Afrique du Sud                              0.0      2035.0
# Albanie                                     0.0        47.0
# Algérie                                     0.0       264.0
# Allemagne                                 -38.0      1609.0
# ...                                         ...         ...
# Venezuela (République bolivarienne du)      0.0       596.0
# Viet Nam                                    0.0      1166.0
# Yémen                                       NaN       237.0
# Zambie                                      0.0        58.0
# Zimbabwe                                    0.0        67.0
#
# [170 rows x 7 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 170 entries, Afghanistan to Zimbabwe
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Production                168 non-null    float64
#  1   Importations - Quantité   170 non-null    float64
#  2   Variation de stock        169 non-null    float64
#  3   Disponibilité intérieure  170 non-null    float64
#  4   Pertes                    67 non-null     float64
#  5   Résidus                   164 non-null    float64
#  6   Nourriture                170 non-null    float64
# dtypes: float64(7)
# memory usage: 14.7+ KB

# %%
# remplacement des NaN par la moyenne pour chaque variable

for att in cleandata.columns:
    a = cleandata.loc[:, att].mean()
    cleandata.loc[:, att] = cleandata.loc[:, att].replace(np.nan, a)
    
display(cleandata)
cleandata.info()
# Out:
#                                         Production  Importations - Quantité  \
# Zone
# Afghanistan                                   28.0                     29.0
# Afrique du Sud                              1667.0                    514.0
# Albanie                                       13.0                     38.0
# Algérie                                      275.0                      2.0
# Allemagne                                   1514.0                    842.0
# ...                                            ...                      ...
# Venezuela (République bolivarienne du)       600.0                     25.0
# Viet Nam                                     918.0                    291.0
# Yémen                                        168.0                     78.0
# Zambie                                        49.0                     12.0
# Zimbabwe                                      69.0                      6.0
#
#                                         Variation de stock  \
# Zone
# Afghanistan                                            0.0
# Afrique du Sud                                        -0.0
# Albanie                                                4.0
# Algérie                                                0.0
# Allemagne                                            -29.0
# ...                                                    ...
# Venezuela (République bolivarienne du)                -1.0
# Viet Nam                                               2.0
# Yémen                                                 -0.0
# Zambie                                                -0.0
# Zimbabwe                                              -0.0
#
#                                         Disponibilité intérieure    Pertes  \
# Zone
# Afghanistan                                                 57.0   2.00000
# Afrique du Sud                                            2118.0  83.00000
# Albanie                                                     47.0  43.58209
# Algérie                                                    277.0  13.00000
# Allemagne                                                 1739.0  43.58209
# ...                                                          ...       ...
# Venezuela (République bolivarienne du)                     626.0  30.00000
# Viet Nam                                                  1206.0  39.00000
# Yémen                                                      246.0   8.00000
# Zambie                                                      60.0   2.00000
# Zimbabwe                                                    76.0   3.00000
#
#                                           Résidus  Nourriture
# Zone
# Afghanistan                              0.000000        55.0
# Afrique du Sud                           0.000000      2035.0
# Albanie                                  0.000000        47.0
# Algérie                                  0.000000       264.0
# Allemagne                              -38.000000      1609.0
# ...                                           ...         ...
# Venezuela (République bolivarienne du)   0.000000       596.0
# Viet Nam                                 0.000000      1166.0
# Yémen                                   -2.835366       237.0
# Zambie                                   0.000000        58.0
# Zimbabwe                                 0.000000        67.0
#
# [170 rows x 7 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 170 entries, Afghanistan to Zimbabwe
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Production                170 non-null    float64
#  1   Importations - Quantité   170 non-null    float64
#  2   Variation de stock        170 non-null    float64
#  3   Disponibilité intérieure  170 non-null    float64
#  4   Pertes                    170 non-null    float64
#  5   Résidus                   170 non-null    float64
#  6   Nourriture                170 non-null    float64
# dtypes: float64(7)
# memory usage: 14.7+ KB

# %%
# données centrées réduites

from sklearn import decomposition
from sklearn import preprocessing

X = cleandata.values
names = cleandata.index
features = cleandata.columns

std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)

X_scaled_table = cleandata.copy(deep = True)

for i in range(len(X_scaled)):
    X_scaled_table.loc[X_scaled_table.index[i]] = X_scaled[i]

X_scaled_table
# Out:
#                                         Production  Importations - Quantité  \
# Zone
# Afghanistan                              -0.281206                -0.325217
# Afrique du Sud                            0.379871                 2.280627
# Albanie                                  -0.287256                -0.276861
# Algérie                                  -0.181581                -0.470284
# Allemagne                                 0.318160                 4.042929
# ...                                            ...                      ...
# Venezuela (République bolivarienne du)   -0.050495                -0.346708
# Viet Nam                                  0.077768                 1.082476
# Yémen                                    -0.224738                -0.061946
# Zambie                                   -0.272736                -0.416556
# Zimbabwe                                 -0.264669                -0.448793
#
#                                         Variation de stock  \
# Zone
# Afghanistan                                      -0.182443
# Afrique du Sud                                   -0.182443
# Albanie                                          -0.129052
# Algérie                                          -0.182443
# Allemagne                                        -0.569521
# ...                                                    ...
# Venezuela (République bolivarienne du)           -0.195790
# Viet Nam                                         -0.155747
# Yémen                                            -0.182443
# Zambie                                           -0.182443
# Zimbabwe                                         -0.182443
#
#                                         Disponibilité intérieure    Pertes  \
# Zone
# Afghanistan                                            -0.289165 -0.552363
# Afrique du Sud                                          0.655926  0.523614
# Albanie                                                -0.293750  0.000000
# Algérie                                                -0.188282 -0.406242
# Allemagne                                               0.482132  0.000000
# ...                                                          ...       ...
# Venezuela (République bolivarienne du)                 -0.028245 -0.180420
# Viet Nam                                                0.237720 -0.060867
# Yémen                                                  -0.202497 -0.472661
# Zambie                                                 -0.287789 -0.552363
# Zimbabwe                                               -0.280452 -0.539079
#
#                                          Résidus  Nourriture
# Zone
# Afghanistan                             0.213231   -0.282618
# Afrique du Sud                          0.213231    0.646850
# Albanie                                 0.213231   -0.286373
# Algérie                                 0.213231   -0.184507
# Allemagne                              -2.644518    0.446873
# ...                                          ...         ...
# Venezuela (République bolivarienne du)  0.213231   -0.028657
# Viet Nam                                0.213231    0.238917
# Yémen                                   0.000000   -0.197182
# Zambie                                  0.213231   -0.281209
# Zimbabwe                                0.213231   -0.276985
#
# [170 rows x 7 columns]

# %%
# établissement de la table des corrélations entre les variables 

corr_table = X_scaled_table.corr(method = "pearson")
corr_table
# Out:
#                           Production  Importations - Quantité  \
# Production                  1.000000                 0.192935
# Importations - Quantité     0.192935                 1.000000
# Variation de stock          0.066443                 0.302510
# Disponibilité intérieure    0.987461                 0.262413
# Pertes                      0.452723                 0.153711
# Résidus                    -0.021536                -0.413447
# Nourriture                  0.988787                 0.261816
#
#                           Variation de stock  Disponibilité intérieure  \
# Production                          0.066443                  0.987461
# Importations - Quantité             0.302510                  0.262413
# Variation de stock                  1.000000                  0.055941
# Disponibilité intérieure            0.055941                  1.000000
# Pertes                             -0.103700                  0.520411
# Résidus                            -0.001994                 -0.001716
# Nourriture                          0.058913                  0.998720
#
#                             Pertes   Résidus  Nourriture
# Production                0.452723 -0.021536    0.988787
# Importations - Quantité   0.153711 -0.413447    0.261816
# Variation de stock       -0.103700 -0.001994    0.058913
# Disponibilité intérieure  0.520411 -0.001716    0.998720
# Pertes                    1.000000  0.008391    0.488509
# Résidus                   0.008391  1.000000   -0.004711
# Nourriture                0.488509 -0.004711    1.000000

# %%
# heatmap des corrélations des variables 

g = sns.heatmap(data = corr_table, 
            cmap = "RdBu", 
            annot = True, 
            linewidth = 1, 
            linecolor = "black")

fig = g.get_figure()

fig.savefig("heatmap.png")

# %%
n_comp = 7

# Calcul des composantes principales
pca = decomposition.PCA(n_components=n_comp)
pca.fit(X_scaled)
# Out:
# PCA(n_components=7)

# %%
# graphique éboulis des valeurs propres

# %matplotlib inline

display_scree_plot(pca)

# %%
# cercle des corrélations

pcs = pca.components_

plan = [(0,1),(2,3),(4,5)]

display_circles(pcs, n_comp, pca, plan, labels = np.array(features))

# %%
#  Classification Hiérarchique Ascendante

from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

def plot_dendrogram():
    
    Z = linkage(X_scaled, "ward")
    
    plt.figure(figsize=(10, 10))
    plt.title('Hierarchical Clustering Dendrogram')
    plt.xlabel('distance')
    dendrogram(
        Z,
        labels=names,
        orientation="top",
    )
    plt.show()

plot_dendrogram()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

fig, ax = plt.subplots()

x = []
y = []

for i in range(2, 10):
    kmeans = KMeans(n_clusters=i).fit(cleandata)
    score = silhouette_score(X_scaled, kmeans.labels_, metric='euclidean')
    x.append(i)
    y.append(score)

plt.title("Variation du Coefficient de Silhouette selon le nombre de cluster")    
ax.set_xlabel("Nombre de clutster")
ax.set_ylabel("Coefficient de Silhouette")
    
plt.plot(x, y)

plt.show()

# %%
# présentation des résultats du kmeans

def heatmap_kmeans(i):
    kmeans = KMeans(n_clusters=i).fit(X_scaled_table)
    
    string = "cluster "
    
    g = sns.clustermap(kmeans.cluster_centers_, 
                   cmap = "RdBu",
                   xticklabels = list(X_scaled_table.columns),
                   yticklabels = [string+str(i) for i in range(i)],
                   annot = True, 
                   linewidth = 1, 
                   linecolor = "black")

heatmap_kmeans(3)

# %%
# affichage des clusters dans les tables

kmeans = KMeans(n_clusters=3).fit(X_scaled_table)
end_table = X_scaled_table.copy(deep = True)
end_table.loc[:, 'cluster_id'] = kmeans.labels_

def sort_countries_by_cluster(cluster_list = set(end_table.cluster_id),
                 col = X_scaled_table.columns, 
                 order = [True, False]):  
    for cluster in cluster_list:
        display(end_table[end_table["cluster_id"]==cluster])

sort_countries_by_cluster()
# Out:
#                                                     Production  \
# Zone
# Allemagne                                             0.318160
# Arabie saoudite                                      -0.044041
# Chine - RAS de Hong-Kong                             -0.282819
# France                                                0.413348
# Japon                                                 0.600902
# Mexique                                               1.017958
# Pays-Bas                                              0.151176
# Pologne                                               0.655757
# Royaume-Uni de Grande-Bretagne et d'Irlande du ...    0.439162
#
#                                                     Importations - Quantité  \
# Zone
# Allemagne                                                          4.042929
# Arabie saoudite                                                    3.398185
# Chine - RAS de Hong-Kong                                           4.392166
# France                                                             2.237644
# Japon                                                              5.262572
# Mexique                                                            4.741403
# Pays-Bas                                                           2.785677
# Pologne                                                           -0.185522
# Royaume-Uni de Grande-Bretagne et d'Irlande du ...                 3.704438
#
#                                                     Variation de stock  \
# Zone
# Allemagne                                                    -0.569521
# Arabie saoudite                                              -1.623975
# Chine - RAS de Hong-Kong                                     -0.342613
# France                                                        2.260155
# Japon                                                        11.283083
# Mexique                                                      -0.262528
# Pays-Bas                                                     -1.276940
# Pologne                                                       2.820751
# Royaume-Uni de Grande-Bretagne et d'Irlande du ...           -0.182443
#
#                                                     Disponibilité intérieure  \
# Zone
# Allemagne                                                           0.482132
# Arabie saoudite                                                     0.342730
# Chine - RAS de Hong-Kong                                           -0.186906
# France                                                              0.406011
# Japon                                                               0.792118
# Mexique                                                             1.619360
# Pays-Bas                                                           -0.144719
# Pologne                                                             0.214792
# Royaume-Uni de Grande-Bretagne et d'Irlande du ...                  0.709119
#
#                                                       Pertes   Résidus  \
# Zone
# Allemagne                                           0.000000 -2.644518
# Arabie saoudite                                     0.000000  0.213231
# Chine - RAS de Hong-Kong                            0.000000 -9.187258
# France                                              0.000000  0.062823
# Japon                                               0.164955  0.213231
# Mexique                                             1.559740  0.000000
# Pays-Bas                                            0.000000 -5.652674
# Pologne                                            -0.220271 -4.223800
# Royaume-Uni de Grande-Bretagne et d'Irlande du ...  0.000000  0.213231
#
#                                                     Nourriture  cluster_id
# Zone
# Allemagne                                             0.446873           0
# Arabie saoudite                                       0.365193           0
# Chine - RAS de Hong-Kong                             -0.124890           0
# France                                                0.388664           0
# Japon                                                 0.798944           0
# Mexique                                               1.596502           0
# Pays-Bas                                             -0.146014           0
# Pologne                                               0.231406           0
# Royaume-Uni de Grande-Bretagne et d'Irlande du ...    0.691915           0
#                                         Production  Importations - Quantité  \
# Zone
# Afghanistan                              -0.281206                -0.325217
# Afrique du Sud                            0.379871                 2.280627
# Albanie                                  -0.287256                -0.276861
# Algérie                                  -0.181581                -0.470284
# Angola                                   -0.275559                 1.007256
# ...                                            ...                      ...
# Venezuela (République bolivarienne du)   -0.050495                -0.346708
# Viet Nam                                  0.077768                 1.082476
# Yémen                                    -0.224738                -0.061946
# Zambie                                   -0.272736                -0.416556
# Zimbabwe                                 -0.264669                -0.448793
#
#                                         Variation de stock  \
# Zone
# Afghanistan                                      -0.182443
# Afrique du Sud                                   -0.182443
# Albanie                                          -0.129052
# Algérie                                          -0.182443
# Angola                                           -0.182443
# ...                                                    ...
# Venezuela (République bolivarienne du)           -0.195790
# Viet Nam                                         -0.155747
# Yémen                                            -0.182443
# Zambie                                           -0.182443
# Zimbabwe                                         -0.182443
#
#                                         Disponibilité intérieure    Pertes  \
# Zone
# Afghanistan                                            -0.289165 -0.552363
# Afrique du Sud                                          0.655926  0.523614
# Albanie                                                -0.293750  0.000000
# Algérie                                                -0.188282 -0.406242
# Angola                                                 -0.169022 -0.552363
# ...                                                          ...       ...
# Venezuela (République bolivarienne du)                 -0.028245 -0.180420
# Viet Nam                                                0.237720 -0.060867
# Yémen                                                  -0.202497 -0.472661
# Zambie                                                 -0.287789 -0.552363
# Zimbabwe                                               -0.280452 -0.539079
#
#                                          Résidus  Nourriture  cluster_id
# Zone
# Afghanistan                             0.213231   -0.282618           1
# Afrique du Sud                          0.213231    0.646850           1
# Albanie                                 0.213231   -0.286373           1
# Algérie                                 0.213231   -0.184507           1
# Angola                                  0.213231   -0.160566           1
# ...                                          ...         ...         ...
# Venezuela (République bolivarienne du)  0.213231   -0.028657           1
# Viet Nam                                0.213231    0.238917           1
# Yémen                                   0.000000   -0.197182           1
# Zambie                                  0.213231   -0.281209           1
# Zimbabwe                                0.213231   -0.276985           1
#
# [158 rows x 8 columns]
#                        Production  Importations - Quantité  \
# Zone
# Brésil                   5.435356                -0.464912
# Chine, continentale      7.062840                 1.947509
# États-Unis d'Amérique    8.546331                 0.179833
#
#                        Variation de stock  Disponibilité intérieure    Pertes  \
# Zone
# Brésil                          -0.182443                  4.262038  0.000000
# Chine, continentale             -0.849819                  8.012595  7.962467
# États-Unis d'Amérique            0.885360                  8.060744  0.000000
#
#                         Résidus  Nourriture  cluster_id
# Zone
# Brésil                 0.213231    4.377393           2
# Chine, continentale    0.138027    7.915002           2
# États-Unis d'Amérique  0.213231    8.188209           2

# %%
# relancer le noyau kernel permet de résoudre les potentiels soucis d’affichage de cette cellule lors de l’ouverture du notebook 

from matplotlib.colors import ListedColormap

# %matplotlib widget

def plot_3D_cluster(a = "Importations - Quantité",\
                    b = "Variation de stock",\
                    c = "Nourriture"):

    plt.rcParams["figure.figsize"] = [7.50, 3.50]
    plt.rcParams["figure.autolayout"] = True
    
    x = end_table[a]
    y = end_table[b]
    z = end_table[c]
    
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    cmap = ListedColormap(sns.color_palette("tab10", 256).as_hex())

    ax.set_xlabel(a)
    ax.set_ylabel(b)
    ax.set_zlabel(c)

    sc = ax.scatter(x, y, z, s=75, c=end_table["cluster_id"], marker='o', cmap=cmap, alpha=1)
    plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

    plt.show()
    
plot_3D_cluster()
# Out:
# C:\Users\arche\AppData\Local\Temp\ipykernel_19164\2604397380.py:19: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# tiedrez.valerie@orange.fr
